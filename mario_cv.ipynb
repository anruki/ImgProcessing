# %% [markdown]
# <a href="https://colab.research.google.com/github/anruki/ImgProcessing/blob/main/mario_cv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Clase Procesamiento de imágenes 28/10/2024
# ## OPEN CV

# %%
# !pip install opencv-python

# %% [markdown]
# ---

# %%
import cv2

# %% [markdown]
# Han desactivado el `imshow()`

# %%
# cv.imshow()

# %% [markdown]
# Por lo que debemos instalar:

# %%
# Especifico de Colab
# !pip install opencv-python
# !pip install opencv_jupyter_ui
# !pip install -q ipycanvas==0.11
from google.colab import output
output.enable_custom_widget_manager
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.8/125.8 kB 9.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 57.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 255.8/255.8 kB 11.6 MB/s eta 0:00:00
# <function google.colab.output._widgets.enable_custom_widget_manager(version='5.0.0a')>

# %% [markdown]
# Para poder usar `imshow()`

# %%
import cv2
from matplotlib import pyplot as plt
import opencv_jupyter_ui as jcv2

# %% [markdown]
# Ahora hay que ver que imágen usamos

# %%
# jcv2.imshow()

# %% [markdown]
# En google images buscamos una imágen

# %%
mario = cv2.imread("mario.png")
jcv2.imshow("",mario)
# plt.imshow(mario)
# plt.show()

# %%
mariogray = cv2.cvtColor(mario,cv2.COLOR_BGR2GRAY)
plt.imshow(mariogray)
plt.show()

# %% [markdown]
# Sale así porque está en BGR y no RGB

# %%
plt.imshow(mariogray,cmap="gray")
plt.show()

# %% [markdown]
# Binarización

# %%
_,mariobin = cv2.threshold(mariogray,120,255,cv2.THRESH_BINARY)
plt.imshow(mariobin,cmap="gray")
plt.show()

# %%
_,mariobin = cv2.threshold(mariogray,100,125,cv2.THRESH_BINARY)
plt.imshow(mariobin,cmap="gray")
plt.show()

# %% [markdown]
# Si quiero aplicar un blur:

# %%
marioblur = cv2.blur(mario,[16,16])
# Defino la matriz del pinceel brush a mano
# tamaño [16,16]
plt.imshow(marioblur,cmap="gray")
plt.show()

# %% [markdown]
# Otro tipo de blur (hay varios tipos):

# %% [markdown]
# [Documentación tipos de blur](https://docs.opencv.org/4.x/d4/d13/tutorial_py_filtering.html)

# %%
plt.imshow(mariobin,cmap="gray")
plt.show()

# %% [markdown]
# ### **Dilate**

# %%
mariodilate = cv2.dilate(mariobin,(16,16),iterations=20)
plt.imshow(mariodilate,cmap="gray")
plt.show()

# %% [markdown]
# ##**Erode**

# %%
marioerode = cv2.erode(mariobin,(16,16),iterations=20)
plt.imshow(marioerode,cmap="gray")
plt.show()

# %% [markdown]
# ## **OPEN & CLOSE**

# %%
marioopen = cv2.dilate(marioerode,(16,16),iterations=20)

marioclose = cv2.erode(mariodilate,(16,16),iterations=20)

# %%
plt.imshow(marioopen,cmap="gray")
plt.show()

# %%
plt.imshow(marioclose,cmap="gray")
plt.show()

# %%
marioOpen2 = cv2.morphologyEx(mariobin,cv2.MORPH_OPEN,(8,8))
plt.imshow(marioOpen2,cmap="gray")
plt.show()

# %% [markdown]
# ## **Clusterización**

# %%
countours, hierarchy = cv2.findContours(marioOpen2,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
print(countours)
# Out:
# (array([[[  0,   0]],
#
#        [[  0, 941]],
#
#        [[883, 941]],
#
#        [[883,   0]]], dtype=int32), array([[[443, 405]],
#
#        [[444, 404]],
#
#        [[445, 404]],
#
#        [[446, 405]],
#
#        [[445, 406]],
#
#        [[444, 406]]], dtype=int32), array([[[436, 302]],
#
#        [[437, 301]],
#
#        [[438, 302]],
#
#        [[437, 303]]], dtype=int32), array([[[441, 301]],
#
#        [[442, 300]],
#
#        [[443, 300]],
#
#        [[444, 301]],
#
#        [[442, 303]],
#
#        [[441, 302]]], dtype=int32), array([[[430, 301]],
#
#        [[431, 300]],
#
#        [[432, 301]],
#
#        [[431, 302]]], dtype=int32), array([[[444, 300]],
#
#        [[445, 299]],
#
#        [[446, 299]],
#
#        [[447, 300]],
#
#        [[446, 301]],
#
#        [[445, 301]]], dtype=int32), array([[[428, 300]],
#
#        [[429, 299]],
#
#        [[430, 300]],
#
#        [[429, 301]]], dtype=int32), array([[[446, 299]],
#
#        [[447, 298]],
#
# ...
